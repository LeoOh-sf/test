# %%
import numpy as np
import pandas as pd

df = pd.read_csv('NFLX.CSV', encoding='cp949')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
df_p_related = df.loc[:, 'Date':'Close']
df_p_related
# Out:
#             Date        Open        High         Low       Close
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001
# ...          ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013
#
# [1009 rows x 5 columns]

# %%
df_2021aft = df[df.Date >= '2021-01-01']
df_2021aft
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 733   2021-01-04  539.000000  540.799988  515.090027  522.859985  522.859985
# 734   2021-01-05  521.549988  526.780029  515.890015  520.799988  520.799988
# 735   2021-01-06  511.970001  513.099976  499.500000  500.489990  500.489990
# 736   2021-01-07  508.279999  516.440002  506.420013  508.890015  508.890015
# 737   2021-01-08  511.309998  513.239990  504.510010  510.399994  510.399994
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 733    4444400
# ...

# %%
# max_val = df[max'Close']
# min_val = df[min'Close']
# df (max_val, min_val)
# a = max(df['Close'])
print (f" Close 최대 값은: {max(df['Close'])}")
print (f" Close 최소 값은: {min(df['Close'] )}")
# Out:
#  Close 최대 값은: 691.690002
#  Close 최소 값은: 233.880005

# %%
df_month = Close.groupby(30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df_month = Close.groupby(30)
#
# NameError: name 'Close' is not defined

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Date'] = df['Date'].dt.strftime('%y-%m')

# %%
df['Date']
# Out:
# 0       18-02
# 1       18-02
# 2       18-02
# 3       18-02
# 4       18-02
#         ...
# 1004    22-01
# 1005    22-02
# 1006    22-02
# 1007    22-02
# 1008    22-02
# Name: Date, Length: 1009, dtype: object

# %%
df_2021aft['Date'] = pd.to_datetime(df_2021aft['Date'])
df_2021aft['Date'] = df_2021aft['Date'].dt.strftime('%y-%m')
df_2021aft
# Out:
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_16360\2746338334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021aft['Date'] = pd.to_datetime(df_2021aft['Date'])
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_16360\2746338334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021aft['Date'] = df_2021aft['Date'].dt.strftime('%y-%m')
#        Date        Open        High         Low       Close   Adj Close  \
# ...

# %%
df_2022aft = df[ df['Date'] >= '2022-01-01' ]
df_2022aft
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 985   2022-01-03  605.609985  609.989990  590.559998  597.369995  597.369995
# 986   2022-01-04  599.909973  600.409973  581.599976  591.150024  591.150024
# 987   2022-01-05  592.000000  592.840027  566.880005  567.520020  567.520020
# 988   2022-01-06  554.340027  563.359985  542.010010  553.289978  553.289978
# 989   2022-01-07  549.460022  553.429993  538.219971  541.059998  541.059998
# 990   2022-01-10  538.489990  543.690002  526.320007  539.849976  539.849976
# 991   2022-01-11  536.989990  543.909973  530.070007  540.840027  540.840027
# 992   2022-01-12  544.270020  544.270020  532.020020  537.219971  537.219971
# 993   2022-01-13  537.059998  540.789978  518.260010  519.200012  519.200012
# 994   2022-01-14  517.599976  538.369995  511.880005  525.690002  525.690002
# 995   2022-01-18  520.080017  521.750000  508.679993  510.799988  510.799988
# ...

# %%
plt.plot(df_2022aft['Date'], df_2022aft['High'],df_2022aft['Date'], df_2022aft['Low'], df_2022aft['Date'], df_2022aft['Close'])
plt.xticks(rotation=45)
plt.show()

#   plt.plot (    x1,   y1   ,   x2,    y2,    x3,    y3   ......)

# %%
df_2021aft.groupby('Date').mean()['Close']

import matplotlib.pyplot as plt

# plt.figure(figsize=(9,6))
plt.plot(df_2021aft.groupby('Date').mean()['Close'])
plt.xticks(rotation=45)
plt.show()
